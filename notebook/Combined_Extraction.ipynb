# %%
# Importing necessary library
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import pywt
import pandas as pd
import os
import time
from scipy import signal
from stingray import lightcurve
import sys
from stingray import Bispectrum
import warnings
import csv
warnings.filterwarnings('ignore')
# %matplotlib inline
# Out:
# c:\Users\Digilab-AMD\anaconda3\envs\skripsi_FH\lib\site-packages\stingray\utils.py:25: UserWarning: pyfftw not installed. Using standard scipy fft
#   warnings.warn("pyfftw not installed. Using standard scipy fft")
# c:\Users\Digilab-AMD\anaconda3\envs\skripsi_FH\lib\site-packages\stingray\utils.py:40: UserWarning: Numba not installed. Faking it
#   warnings.warn("Numba not installed. Faking it")

# %%
# file that will be skipped because of information loss
zeros_test = ['co2a0000368_91.csv', 'co2c0000341_26.csv']
zeros_train = ['co2a0000368_0.csv', 'co2a0000368_1.csv', 'co2a0000368_2.csv', 'co2a0000368_3.csv', 'co2a0000368_4.csv', 'co2a0000368_5.csv', 'co2c0000341_27.csv']

# %%
def calcBispecMag(df_data, t, lag):
    # Compute the bispectrum of the signal
    lc = lightcurve.Lightcurve(t,df_data.T)
    bs = Bispectrum(lc, maxlag=lag)

    # Plot the bispectrum using contour plots
    # plt.contour(bs.freq, bs.freq, bs.bispec_mag)
    # plt.xlabel('f1')
    # plt.ylabel('f2')
    # plt.show()

    # Plot the bispectrum using mesh plots
    # fig = plt.figure()
    # ax = fig.add_subplot(111, projection='3d')
    # X, Y = np.meshgrid(bs.freq, bs.freq)
    # ax.plot_surface(X, Y, bs.bispec_mag)
    # ax.set_xlabel('f1')
    # ax.set_ylabel('f2')
    # ax.set_zlabel('Bispectrum')
    # plt.show()

    return bs.bispec_mag

# %%
def gkernel(k=2, l=1, sig=20):
    """
    Gaussian Kernel Creator via given length and sigma
    """

    ax = np.linspace(-(l - 1) / 2., (l - 1) / 2., l)
    bx = np.linspace(-(k - 1) / 2., (k - 1) / 2., k)

    xx, yy = np.meshgrid(ax, bx)

    kernel = np.exp(-0.5 * (np.square(xx) + np.square(yy)) / np.square(sig))

    return kernel / np.max(kernel)

# %%
def create_feature(bispectrum, pyramid, fil_size):
    fsize = len(fil_size)
    feature_matrix = np.zeros([fsize,fsize])
    xtrack = 0
    ytrack = 0
    for xdim in range(fsize):
        for ydim in range(fsize):
            x,y = fil_size[xdim], fil_size[ydim]
            # print(xtrack, ytrack)
            
            feature_matrix[xdim][ydim] = np.mean(bispectrum[xtrack:xtrack+x, ytrack:ytrack+y] * pyramid[xtrack:xtrack+x, ytrack:ytrack+y])
            ytrack = ytrack+y
        ytrack = 0
        xtrack = xtrack+x
    final_feature = feature_matrix[np.triu(np.ones_like(feature_matrix, dtype=bool))]
    final_feature = final_feature[~np.isnan(final_feature)]

    return feature_matrix

    # x, y = np.meshgrid(np.arange(256), np.arange(256))
    # z = overall
    # z = z[:-1, :-1]
    # z_min, z_max = -np.abs(z).max(), np.abs(z).max()

    # plt.subplot()

    # plt.pcolormesh(x, y, z, 
    #             cmap =cm.coolwarm, 
    #             vmin = z_min, 
    #             vmax = z_max,
    #             edgecolors = 'face',
    #             shading ='flat')

    # plt.title('Filter')

    # # set the limits of the plot
    # # to the limits of the data
    # plt.axis([x.min(), x.max(), y.min(), y.max()])

    # plt.colorbar()
    # plt.show()

    # fig, ax = plt.subplots(subplot_kw={"projection": "3d"}, figsize=(10, 5))
    # ax = plt.axes(projection="3d")
    # x2d, y2d = np.meshgrid(np.arange(256), np.arange(256))
    # ax.plot_surface(x2d, y2d, overall, cmap=cm.coolwarm,
    #                         linewidth=0, antialiased=False)
    # ax.set_xlabel('x')
    # ax.set_ylabel('y')
    # ax.set_zlabel('height')
    # plt.show()

# %%
# Define sampling frequency
fs = 256
t = np.arange(0, 1, 1/fs)

def get_csv_EEG(filename):
    # Load data from CSV
    data = np.loadtxt(filename, delimiter=",", skiprows=1, usecols=range(3,259))
    channel_name = np.loadtxt(filename, delimiter=",", skiprows=1, usecols=1, dtype='str', encoding='utf-8')
    
    df_data = pd.DataFrame(data.T, columns=channel_name)

    df_data = df_data.drop(columns=['X', 'Y', 'nd'])

    return df_data, df_data.columns

# %%
def calcCumulantOrde3(df_data, t, lag):
    # Compute the bispectrum of the signal
    lc = lightcurve.Lightcurve(t,df_data.T)
    bs = Bispectrum(lc, maxlag=lag)

    # Plot the bispectrum using contour plots
    # plt.contour(bs.freq, bs.freq, bs.bispec_mag)
    # plt.xlabel('f1')
    # plt.ylabel('f2')
    # plt.show()

    # # Plot the bispectrum using mesh plots
    # fig = plt.figure()
    # ax = fig.add_subplot(111, projection='3d')
    # X, Y = np.meshgrid(bs.freq, bs.freq)
    # ax.plot_surface(X, Y, bs.bispec_mag)
    # ax.set_xlabel('f1')
    # ax.set_ylabel('f2')
    # ax.set_zlabel('Bispectrum')
    # plt.show()

    return bs

# %%
def calcWaveletDec(bs):
    # Select wavelet and decomposition level
    wavelet = 'db4'
    level = 5

    # Deecompose signal
    coeffs = pywt.wavedec2(bs.cum3, wavelet, level=level)

    # print(coeffs)
    # Visualize
    
    cA5 = coeffs[0][np.triu(np.ones_like(coeffs[0], dtype=bool))]
    cD5 = np.ravel([coeffs[1][0], coeffs[1][1], coeffs[1][2]])
    cD4 = np.ravel([coeffs[2][0], coeffs[2][1], coeffs[2][2]])
    cD3 = np.ravel([coeffs[3][0], coeffs[3][1], coeffs[3][2]])
    cD2 = np.ravel([coeffs[4][0], coeffs[4][1], coeffs[4][2]])
    cD1 = np.ravel([coeffs[5][0], coeffs[5][1], coeffs[5][2]])
    
    coeff = [cA5,cD5,cD4,cD3,cD2,cD1]
    # fig, axs = plt.subplots(6)
    
    
    # axs[0].plot(cA5)
    # axs[0].set_title(f'Approximation - Level 5')
    # axs[1].plot(cD5)
    # axs[1].set_title(f'Detail - Level 5')
    # axs[2].plot(cD4)
    # axs[2].set_title(f'Detail - Level 4')
    # axs[3].plot(cD3)
    # axs[3].set_title(f'Detail - Level 3')
    # axs[4].plot(cD2)
    # axs[4].set_title(f'Detail - Level 2')
    # axs[5].plot(cD1)
    # axs[5].set_title(f'Detail - Level 1')
    # plt.show()

    return coeffs

# %%
def calcRelativeEnergy(coeffs, df_data):
    # Calculate relative wavelet energy
    energies = []
    for c in coeffs:
        energies.append(np.sum(np.square(c)))

    decomp = ['A5', 'D1', 'D2', 'D3', 'D4', 'D5']

    energies[1:6] = energies[-1:-6:-1]

    total_energy = np.sum(energies)
    relative_energies = [(e / total_energy) * 100 for e in energies]

    # print(relative_energies)

    # plt.plot(decomp, energies)
    # plt.xlabel('Dimension Number')
    # plt.ylabel('Wavelet Bispectrum Energy')
    # plt.show()

    # plt.plot(decomp, relative_energies)
    # plt.xlabel('Dimension Number')
    # plt.ylabel('Relative Wavelet Bispectrum Energy')
    # plt.show()

    return relative_energies

# %% [markdown]
# ### Bispectrum 2d 25 x 1

# %%
def extract_bispec2dFlat(directory, lag, filter_dim = 5):
    if 'test' in directory.lower():
        dest_dir = os.path.join('../Feature','Bispectrum2DFlat','Test')
    else:
        dest_dir = os.path.join('../Feature','Bispectrum2DFlat','Train')
    bis_dim = lag
    big_fil_size = bis_dim //2
    sigma = bis_dim//8
    if sigma == 0:
        sigma = 1
    fil_size = [big_fil_size // (2 ** i) for i in range(filter_dim)]
    
    if sum(fil_size) != bis_dim:
            fil_size = [value for value in fil_size if value != 0]
            if len(fil_size) == 1:
                fil_size.append(fil_size[0])
    
    fil_size[-1] = fil_size[-2] 
    pyramid = np.zeros([bis_dim,bis_dim])
    xtrack, ytrack = 0,0
    print(fil_size)
    for xdim in range(len(fil_size)):
        for ydim in range(len(fil_size)):
            x,y = fil_size[xdim], fil_size[ydim]
            pyramid[xtrack:xtrack+x, ytrack:ytrack+y] = gkernel(x, y, sigma)
            ytrack = ytrack+y
        ytrack = 0
        xtrack = xtrack+x
    recap = pd.DataFrame(columns=['Wall Time', 'CPU Time'])
    for foldername in os.listdir(directory):
        folder = os.path.join(directory, foldername)
        if os.path.isdir(folder):
            des_dir = os.path.join(directory.replace('CSV', 'bispectrum2dFlat')[3:]+"_" + str(lag),foldername).lower()
            des_dir = os.path.join(dest_dir, des_dir)
            files = os.listdir(folder)
            for filename in files:
                cpu_start = time.process_time()
                wt_start = time.time()
                if filename in zeros_train or filename in zeros_test:
                    continue
                rel_path = os.path.join(directory, foldername, filename)
                if 'metadata' in filename.lower():
                    continue
                trial_number = filename.split('.')[0].split('_')[1]
                des_file = foldername+'_'+ str(trial_number) + '_bispectrum2dFlat' +'.npy'
                if not os.path.exists(des_dir):
                    os.makedirs(des_dir)
                des_path = os.path.join(des_dir, des_file)
                if os.path.exists(des_path):
                    continue
                df_data, channel_name = get_csv_EEG(rel_path)
                bispectrum = []
                for channel in channel_name:
                    magnitude = calcBispecMag(df_data[channel], t, lag)
                    magnitude = magnitude[:256, :256]
                    feature = create_feature(magnitude,pyramid,fil_size)
                    bispectrum.append(feature.flatten())
                bispectrum = np.array(bispectrum)
                np.save(des_path, bispectrum)
                wt_end = time.time()
                cpu_end = time.process_time()
                wall_time = wt_end - wt_start
                cpu_time = cpu_end - cpu_start
                recap_temp = pd.DataFrame([[wall_time, cpu_time]],columns=recap.columns)
                recap = pd.concat([recap, recap_temp], ignore_index=True)
                # pd.DataFrame(RWB.T).to_csv(des_path, index=False)
    recap_dir = os.path.join('./logs/Execution',directory.split('/')[1])
    if not os.path.exists(recap_dir):
        os.makedirs(recap_dir)
    recap_path = os.path.join(recap_dir,'recap_bispectrum2dFlat'+str(lag)+'.csv')
    recap.to_csv(recap_path)

# %% [markdown]
# ### Bispectrum 2d 5 x 5

# %%
def extract_bispec2d(directory, lag, filter_dim = 5):
    if 'test' in directory.lower():
        dest_dir = os.path.join('../Feature','Bispectrum2D','Test')
    else:
        dest_dir = os.path.join('../Feature','Bispectrum2D','Train')
    bis_dim = lag
    big_fil_size = bis_dim //2
    sigma = bis_dim//8
    if sigma == 0:
        sigma = 1
    fil_size = [big_fil_size // (2 ** i) for i in range(filter_dim)]
    
    if sum(fil_size) != bis_dim:
            fil_size = [value for value in fil_size if value != 0]
            if len(fil_size) == 1:
                fil_size.append(fil_size[0])
    
    fil_size[-1] = fil_size[-2] 
    pyramid = np.zeros([bis_dim,bis_dim])
    xtrack, ytrack = 0,0
    print(fil_size)
    for xdim in range(len(fil_size)):
        for ydim in range(len(fil_size)):
            x,y = fil_size[xdim], fil_size[ydim]
            pyramid[xtrack:xtrack+x, ytrack:ytrack+y] = gkernel(x, y, sigma)
            ytrack = ytrack+y
        ytrack = 0
        xtrack = xtrack+x
    recap = pd.DataFrame(columns=['Wall Time', 'CPU Time'])
    for foldername in os.listdir(directory):
        folder = os.path.join(directory, foldername)
        if os.path.isdir(folder):
            des_dir = os.path.join(directory.replace('CSV', 'bispectrum2d')[3:]+"_" + str(lag),foldername).lower()
            des_dir = os.path.join(dest_dir, des_dir)
            files = os.listdir(folder)
            for filename in files:
                cpu_start = time.process_time()
                wt_start = time.time()
                if filename in zeros_train or filename in zeros_test:
                    continue
                rel_path = os.path.join(directory, foldername, filename)
                if 'metadata' in filename.lower():
                    continue
                trial_number = filename.split('.')[0].split('_')[1]
                des_file = foldername+'_'+ str(trial_number) + '_bispectrum2d' +'.npy'
                if not os.path.exists(des_dir):
                    os.makedirs(des_dir)
                des_path = os.path.join(des_dir, des_file)
                if os.path.exists(des_path):
                    continue
                df_data, channel_name = get_csv_EEG(rel_path)
                bispectrum = []
                for channel in channel_name:
                    magnitude = calcBispecMag(df_data[channel], t, lag)
                    magnitude = magnitude[:256, :256]
                    feature = create_feature(magnitude,pyramid,fil_size)
                    bispectrum.append(feature)
                bispectrum = np.array(bispectrum)
                print(des_path)
                np.save(des_path, bispectrum)
                wt_end = time.time()
                cpu_end = time.process_time()
                wall_time = wt_end - wt_start
                cpu_time = cpu_end - cpu_start
                recap_temp = pd.DataFrame([[wall_time, cpu_time]],columns=recap.columns)
                recap = pd.concat([recap, recap_temp], ignore_index=True)
                # pd.DataFrame(RWB.T).to_csv(des_path, index=False)
    recap_dir = os.path.join('./logs/Execution',directory.split('/')[1])
    if not os.path.exists(recap_dir):
        os.makedirs(recap_dir)
    recap_path = os.path.join(recap_dir,'recap_bispectrum2d'+str(lag)+'.csv')
    recap.to_csv(recap_path)

# %% [markdown]
# ### RWB 2D

# %%
def extract_rwb2d(directory, lag):
    if 'test' in directory.lower():
        dest_dir = os.path.join('../Feature','RWB2D','Test')
    else:
        dest_dir = os.path.join('../Feature','RWB2D','Train')
    recap = pd.DataFrame(columns=['Wall Time', 'CPU Time'])
    for foldername in os.listdir(directory):
        folder = os.path.join(directory, foldername)
        if os.path.isdir(folder):
            des_dir = os.path.join(directory.replace('CSV', 'rwb2d')[3:]+"_" + str(lag),foldername).lower()
            des_dir = os.path.join(dest_dir, des_dir)
            files = os.listdir(folder)
            for filename in files:
                cpu_start = time.process_time()
                wt_start = time.time()
                if filename in zeros_train or filename in zeros_test:
                    continue
                rel_path = os.path.join(directory, foldername, filename)
                if 'metadata' in filename.lower():
                    continue
                trial_number = filename.split('.')[0].split('_')[1]
                df_data, channel_name = get_csv_EEG(rel_path)
                des_file = foldername+'_'+ str(trial_number) + '_rwb2d' +'.npy'
                if not os.path.exists(des_dir):
                    os.makedirs(des_dir)
                des_path = os.path.join(des_dir, des_file)
                if os.path.exists(des_path):
                    continue
                RWB = []
                for channel in channel_name:
                    y = df_data[channel]; # sinyal per channel
                    # N = len(y);
                    # z = y - np.mean(y);
                    # nsamp = len (y[0])
                    relative_energies = calcRelativeEnergy(calcWaveletDec(calcCumulantOrde3(y, t, lag)), y)
                    RWB.append(relative_energies)
                RWB = np.array(RWB)
                np.save(des_path, RWB)
                wt_end = time.time()
                cpu_end = time.process_time()
                wall_time = wt_end - wt_start
                cpu_time = cpu_end - cpu_start
                recap_temp = pd.DataFrame([[wall_time, cpu_time]],columns=recap.columns)
                recap = pd.concat([recap, recap_temp], ignore_index=True)
                # pd.DataFrame(RWB.T).to_csv(des_path, index=False)
    recap_dir = os.path.join('./logs/Execution',directory.split('/')[1])
    if not os.path.exists(recap_dir):
        os.makedirs(recap_dir)
    recap_path = os.path.join(recap_dir,'recap_rwb2d'+str(lag)+'.csv')
    recap.to_csv(recap_path)

# %% [markdown]
# ### Bispectrum 1D

# %%
def extract_bispec1d(directory, lag, filter_dim = 5):
    if 'test' in directory.lower():
        dest_dir = os.path.join('../Feature','Bispectrum1D','Test')
    else:
        dest_dir = os.path.join('../Feature','Bispectrum1D','Train')
    bis_dim = lag
    big_fil_size = bis_dim //2
    sigma = bis_dim//8
    if sigma == 0:
        sigma = 1
    fil_size = [big_fil_size // (2 ** i) for i in range(filter_dim)]
    
    if sum(fil_size) != bis_dim:
            fil_size = [value for value in fil_size if value != 0]
            if len(fil_size) == 1:
                fil_size.append(fil_size[0])
    
    fil_size[-1] = fil_size[-2] 
    pyramid = np.zeros([bis_dim,bis_dim])
    xtrack, ytrack = 0,0
    print(fil_size)
    for xdim in range(len(fil_size)):
        for ydim in range(len(fil_size)):
            x,y = fil_size[xdim], fil_size[ydim]
            pyramid[xtrack:xtrack+x, ytrack:ytrack+y] = gkernel(x, y, sigma)
            ytrack = ytrack+y
        ytrack = 0
        xtrack = xtrack+x
    recap = pd.DataFrame(columns=['Wall Time', 'CPU Time'])
    for foldername in os.listdir(directory):
        folder = os.path.join(directory, foldername)
        if os.path.isdir(folder):
            des_dir = os.path.join(directory.replace('CSV', 'bispectrum1d')[3:]+"_" + str(lag),foldername).lower()
            des_dir = os.path.join(dest_dir, des_dir)
            files = os.listdir(folder)
            for filename in files:
                cpu_start = time.process_time()
                wt_start = time.time()
                if filename in zeros_train or filename in zeros_test:
                    continue
                rel_path = os.path.join(directory, foldername, filename)
                if 'metadata' in filename.lower():
                    continue
                trial_number = filename.split('.')[0].split('_')[1]
                des_file = foldername+'_'+ str(trial_number) + '_bispectrum1d' +'.npy'
                if not os.path.exists(des_dir):
                    os.makedirs(des_dir)
                des_path = os.path.join(des_dir, des_file)
                if os.path.exists(des_path):
                    continue
                df_data, channel_name = get_csv_EEG(rel_path)
                bispectrum = []
                for channel in channel_name:
                    magnitude = calcBispecMag(df_data[channel], t, lag)
                    magnitude = magnitude[:256, :256]
                    feature = create_feature(magnitude,pyramid,fil_size)
                    bispectrum.append(feature.flatten())
                bispectrum = np.array(bispectrum)
                bispectrum = bispectrum.flatten()
                np.save(des_path, bispectrum)
                wt_end = time.time()
                cpu_end = time.process_time()
                wall_time = wt_end - wt_start
                cpu_time = cpu_end - cpu_start
                recap_temp = pd.DataFrame([[wall_time, cpu_time]],columns=recap.columns)
                recap = pd.concat([recap, recap_temp], ignore_index=True)
                # pd.DataFrame(RWB.T).to_csv(des_path, index=False)
    recap_dir = os.path.join('./logs/Execution',directory.split('/')[1])
    if not os.path.exists(recap_dir):
        os.makedirs(recap_dir)
    recap_path = os.path.join(recap_dir,'recap_bispectrum1d'+str(lag)+'.csv')
    recap.to_csv(recap_path)

# %% [markdown]
# ### Main Program

# %%
lags = [256, 128, 64, 32, 16, 8, 4, 2]
for lag in lags:
    extract_bispec1d('../SMNI_CMI_TEST_CSV', lag)
    extract_rwb2d('../SMNI_CMI_TEST_CSV', lag)
    extract_bispec2dFlat('../SMNI_CMI_TEST_CSV', lag)
    extract_bispec2d('../SMNI_CMI_TEST_CSV', lag)
    extract_bispec1d('../SMNI_CMI_TRAIN_CSV', lag)
    extract_bispec2d('../SMNI_CMI_TRAIN_CSV', lag)
    extract_bispec2dFlat('../SMNI_CMI_TRAIN_CSV', lag)
    extract_rwb2d('../SMNI_CMI_TRAIN_CSV', lag)
# Out:
# [128, 64, 32, 16, 16]
# [128, 64, 32, 16, 16]
# [128, 64, 32, 16, 16]
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_103_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_111_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_50_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_93_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000364\co2a0000364_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_101_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_103_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_107_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_109_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_113_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_119_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_93_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000365\co2a0000365_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_37_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_51_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000368\co2a0000368_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_51_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000369\co2a0000369_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000370\co2a0000370_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_35_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000371\co2a0000371_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_35_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_51_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000372\co2a0000372_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_107_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000375\co2a0000375_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_101_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_50_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_52_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_54_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_56_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_58_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000377\co2a0000377_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2a0000378\co2a0000378_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_101_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_103_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_107_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_111_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_115_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_52_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_54_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_66_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_68_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_93_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000337\co2c0000337_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000338\co2c0000338_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_101_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_109_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_113_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_119_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_48_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_50_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_54_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_56_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_58_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_60_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000339\co2c0000339_99_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_103_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_107_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_109_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_111_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_113_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_115_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_46_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_87_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_89_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_93_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_95_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000340\co2c0000340_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_101_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_105_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_107_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_117_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_40_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_42_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_44_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_63_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_67_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_69_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_73_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_81_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_85_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_91_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000341\co2c0000341_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_34_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_35_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_36_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_38_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Test\smni_cmi_test_bispectrum2d_256\co2c0000342\co2c0000342_40_bispectrum2d.npy
# ...
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000340\co2c0000340_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000340\co2c0000340_8_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000340\co2c0000340_83_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000340\co2c0000340_9_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000340\co2c0000340_97_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_0_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_1_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_10_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_11_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_12_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_13_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_14_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_15_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_16_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_18_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_19_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_20_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_21_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_23_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_3_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_31_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_33_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_35_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_5_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_51_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_6_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_7_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_8_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000341\co2c0000341_9_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_0_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_1_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_11_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_12_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_15_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_16_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_18_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_25_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_3_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_31_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_39_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_43_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_45_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_5_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_51_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_7_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000344\co2c0000344_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_0_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_1_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_10_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_11_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_12_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_13_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_14_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_15_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_16_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_17_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_18_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_19_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_2_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_21_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_23_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_25_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_27_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_29_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_3_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_31_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_33_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_37_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_4_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_5_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_6_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_7_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_8_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000345\co2c0000345_9_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_0_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_1_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_10_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_11_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_13_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_14_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_15_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_17_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_18_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_19_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_21_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_23_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_25_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_27_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_28_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_29_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_3_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_31_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_33_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_37_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_4_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_41_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_5_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_6_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_7_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_8_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000346\co2c0000346_9_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_0_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_1_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_14_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_18_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_19_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_2_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_22_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_23_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_24_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_26_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_29_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_30_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_31_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_32_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_47_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_49_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_5_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_53_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_55_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_57_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_59_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_61_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_65_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_7_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_71_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_75_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_77_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_79_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_8_bispectrum2d.npy
# ../Feature\Bispectrum2D\Train\smni_cmi_train_bispectrum2d_2\co2c0000347\co2c0000347_81_bispectrum2d.npy
# [1, 1]
